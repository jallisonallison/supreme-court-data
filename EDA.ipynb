# %% [markdown]
# ### 0. Import Libraries

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)
import numpy as np
from PyPDF2 import PdfReader
# Out:
# /var/folders/rc/krqtgkpd3x52pdvzx7t5j_v80000gn/T/ipykernel_18832/1347777449.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)

# %% [markdown]
# ### 1. Read Data

# %%
path = '/Users/jallison/Documents/GitHub/SupremeCourtData/Data/SCDB_2022_01_caseCentered_LegalProvision.csv'
df = pd.read_csv(path, encoding='Windows-1252')
df.head()
# Out:
#      caseId     docketId    caseIssuesId             voteId dateDecision  decisionType       usCite       sctCite       ledCite             lexisCite  term  naturalCourt   chief docket                                                                                caseName dateArgument   dateRearg  petitioner  petitionerState  respondent  respondentState  jurisdiction  adminAction  adminActionState  threeJudgeFdc  caseOrigin  caseOriginState  caseSource  caseSourceState  lcDisagreement  certReason  lcDisposition  lcDispositionDirection  declarationUncon  caseDisposition  caseDispositionUnusual  partyWinning  precedentAlteration  voteUnclear    issue  issueArea  decisionDirection  decisionDirectionDissent  authorityDecision1  authorityDecision2  lawType  lawSupp         lawMinor  majOpinWriter  majOpinAssigner  splitVote  majVotes  minVotes
# ...

# %%
# Data Dictionary from WashingtonUniversityLaw, read from a .pdf
pdf_path = '/Users/jallison/Documents/GitHub/SupremeCourtData/Data/Data Dictionary.pdf'
reader = PdfReader(pdf_path)

full_data_dictionary = ''
for page in range(len(reader.pages)):
    x = reader.pages[page]
    y = x.extract_text()
    full_data_dictionary = full_data_dictionary + ' \n ' + y

# %%
# Out:
# Empty DataFrame
# Columns: [caseId, docketId, caseIssuesId, voteId, dateDecision, decisionType, usCite, sctCite, ledCite, lexisCite, term, naturalCourt, chief, docket, caseName, dateArgument, dateRearg, petitioner, petitionerState, respondent, respondentState, jurisdiction, adminAction, adminActionState, threeJudgeFdc, caseOrigin, caseOriginState, caseSource, caseSourceState, lcDisagreement, certReason, lcDisposition, lcDispositionDirection, declarationUncon, caseDisposition, caseDispositionUnusual, partyWinning, precedentAlteration, voteUnclear, issue, issueArea, decisionDirection, decisionDirectionDissent, authorityDecision1, authorityDecision2, lawType, lawSupp, lawMinor, majOpinWriter, majOpinAssigner, splitVote, majVotes, minVotes]
# Index: []

# %%
df_DataDictionary
# Out:
# Empty DataFrame
# Columns: [caseId, docketId, caseIssuesId, voteId, dateDecision, decisionType, usCite, sctCite, ledCite, lexisCite, term, naturalCourt, chief, docket, caseName, dateArgument, dateRearg, petitioner, petitionerState, respondent, respondentState, jurisdiction, adminAction, adminActionState, threeJudgeFdc, caseOrigin, caseOriginState, caseSource, caseSourceState, lcDisagreement, certReason, lcDisposition, lcDispositionDirection, declarationUncon, caseDisposition, caseDispositionUnusual, partyWinning, precedentAlteration, voteUnclear, issue, issueArea, decisionDirection, decisionDirectionDissent, authorityDecision1, authorityDecision2, lawType, lawSupp, lawMinor, majOpinWriter, majOpinAssigner, splitVote, majVotes, minVotes]
# Index: []

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13706 entries, 0 to 13705
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   caseId                    13706 non-null  object
#  1   docketId                  13706 non-null  object
#  2   caseIssuesId              13706 non-null  object
#  3   voteId                    13706 non-null  object
#  4   dateDecision              13706 non-null  object
#  5   decisionType              13706 non-null  int64
#  6   usCite                    13209 non-null  object
#  7   sctCite                   13702 non-null  object
#  8   ledCite                   13700 non-null  object
#  9   lexisCite                 13706 non-null  object
#  10  term                      13706 non-null  int64
#  11  naturalCourt              13706 non-null  int64
#  12  chief                     13706 non-null  object
# ...
